# %%
import pandas as pd
gdpdata =pd.read_csv("GDP.csv")

# %%
gdpdata # Task 1: load data
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0             1            Monaco    Europe             0         0
# 1             2     Liechtenstein    Europe             0         0
# 2             3        Luxembourg    Europe        132372      2023
# 3             4           Ireland    Europe        114581      2023
# 4             5           Bermuda  Americas             0         0
# ..          ...               ...       ...           ...       ...
# 218         219            Malawi    Africa           496      2023
# 219         220       South Sudan    Africa           467      2023
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0                234316            2021       234317    2021
# ...

# %%
gdpdata.head(3) # Task 2a: Display first 3 rows of the dataframe
# Out:
#    Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0           1            Monaco    Europe             0         0
# 1           2     Liechtenstein    Europe             0         0
# 2           3        Luxembourg    Europe        132372      2023
#
#    WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0              234316            2021       234317    2021
# 1              157755            2020       169260    2021
# 2              133590            2021       133745    2021

# %%
gdpdata.tail(3) # Task 2b: Display last 3 rows of the dataframe
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 220                 480            2021          505    2021
# 221                 369            2021          373    2021
# 222                 222            2021          311    2021

# %%
gdpdata.shape # Task 3: Display dimensions of data set
# Out:
# (223, 9)

# %%
gdpdata.info() # Task 4: Information of DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          223 non-null    int64
#  1   Country/Territory   223 non-null    object
#  2   UN_Region           223 non-null    object
#  3   IMF_Estimate        223 non-null    int64
#  4   IMF_Year            223 non-null    int64
#  5   WorldBank_Estimate  223 non-null    int64
#  6   WorldBank_Year      223 non-null    int64
#  7   UN_Estimate         223 non-null    int64
#  8   UN_Year             223 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 15.8+ KB

# %%
topcountry = gdpdata.loc[1:10,['Country/Territory','IMF_Estimate','UN_Year']] # Task 5: Subset of top 10 Countries
topcountry
# Out:
#    Country/Territory  IMF_Estimate UN_Year
# 1      Liechtenstein             0    2021
# 2         Luxembourg        132372    2021
# 3            Ireland        114581    2021
# 4            Bermuda             0    2021
# 5             Norway        101103    2021
# 6        Switzerland         98767    2021
# 7          Singapore         91100    2021
# 8        Isle of Man             0       0
# 9     Cayman Islands             0    2021
# 10             Qatar         83891    2021

# %%
topregion = gdpdata.iloc[1:10,1:5] # Task 6: Subset of top 10 UN_Region
topregion
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year
# 1     Liechtenstein    Europe             0         0
# 2        Luxembourg    Europe        132372      2023
# 3           Ireland    Europe        114581      2023
# 4           Bermuda  Americas             0         0
# 5            Norway    Europe        101103      2023
# 6       Switzerland    Europe         98767      2023
# 7         Singapore      Asia         91100      2023
# 8       Isle of Man    Europe             0         0
# 9    Cayman Islands  Americas             0         0

# %%
imf=gdpdata[gdpdata['IMF_Estimate']>100] # Task 7a: IMF Estimate > 100
imf
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 2             3        Luxembourg    Europe        132372      2023
# 3             4           Ireland    Europe        114581      2023
# 5             6            Norway    Europe        101103      2023
# 6             7       Switzerland    Europe         98767      2023
# 7             8         Singapore      Asia         91100      2023
# ..          ...               ...       ...           ...       ...
# 218         219            Malawi    Africa           496      2023
# 219         220       South Sudan    Africa           467      2023
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 2                133590            2021       133745    2021
# ...

# %%
wb=gdpdata[gdpdata['WorldBank_Estimate']<50] # Task 7b: WorldBank Estimate < 50
wb
# Out:
#      Unnamed: 0       Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 30           31  British Virgin Islands  Americas             0         0
# 45           46                  Taiwan      Asia         33907      2023
# 75           76            Cook Islands   Oceania             0         0
# 76           77                Anguilla  Americas             0         0
# 84           85              Montserrat  Americas             0         0
# 195         196                Zanzibar    Africa             0         0
# 211         212             North Korea      Asia             0         0
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 30                    0               0        49444    2021
# 45                    0               0            0       0
# 75                    0               0        19264    2021
# 76                    0               0        19216    2021
# 84                    0               0        16199    2021
# ...

# %%
un=gdpdata[(gdpdata['UN_Estimate']>=750) & (gdpdata['UN_Estimate']<=1000)] # Task 7c: UN Estimate is between 75 and 100
un
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 187         188          Ethiopia    Africa          1475      2023
# 194         195        Tajikistan      Asia          1277      2023
# 198         199            Uganda    Africa          1105      2023
# 199         200              Togo    Africa           990      2023
# 200         201             Sudan    Africa           975      2023
# 201         202     Guinea-Bissau    Africa           974      2023
# 202         203            Rwanda    Africa           970      2023
# 203         204             Syria      Asia             0         0
# 204         205      Burkina Faso    Africa           900      2023
# 205         206              Mali    Africa           889      2023
# 206         207            Gambia    Africa           861      2023
# 210         211              Chad    Africa           667      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# ...

# %%
gdpdata['IMF_Estimate'].describe() # Task 8a: Summary Statistic for IMF_Estimate
# Out:
# count       223.000000
# mean      15351.632287
# std       22550.899445
# min           0.000000
# 25%        1406.500000
# 50%        5421.000000
# 75%       19697.000000
# max      132372.000000
# Name: IMF_Estimate, dtype: float64

# %%
gdpdata['WorldBank_Estimate'].describe() # Task 8b: Summary Statistic for WorldBank_Estimate
# Out:
# count       223.000000
# mean      18927.417040
# std       29103.564915
# min           0.000000
# 25%        2273.500000
# 50%        6805.000000
# 75%       23715.000000
# max      234316.000000
# Name: WorldBank_Estimate, dtype: float64

# %%
gdpdata['UN_Estimate'].describe() # Task 8c: Summary Statistic for UN_Estimate
# Out:
# count       223.000000
# mean      17767.304933
# std       28698.104167
# min           0.000000
# 25%        2039.000000
# 50%        6396.000000
# 75%       20740.000000
# max      234317.000000
# Name: UN_Estimate, dtype: float64

# %%
countryperregion = gdpdata.groupby('UN_Region')['Country/Territory'].nunique() # Task 9a: Number of countries in each UN Region
countryperregion
# Out:
# UN_Region
# Africa      55
# Americas    48
# Asia        51
# Europe      48
# Oceania     20
# World        1
# Name: Country/Territory, dtype: int64

# %%
africa = gdpdata[gdpdata['UN_Region']=='Africa'] # Task 9b: Create a subset Africa
africa
# Out:
#      Unnamed: 0         Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 73           74                Seychelles    Africa         19536      2023
# 100         101                 Mauritius    Africa         11548      2023
# 106         107         Equatorial Guinea    Africa          9777      2023
# 109         110                     Gabon    Africa          9294      2023
# 118         119                  Botswana    Africa          7270      2023
# 121         122                     Libya    Africa          6763      2023
# 124         125              South Africa    Africa          6485      2023
# 138         139                   Namibia    Africa          5100      2023
# 143         144                   Algeria    Africa          4481      2023
# 147         148                Cape Verde    Africa          4278      2023
# 149         150                  Eswatini    Africa          4146      2023
# ...

# %%
europe = gdpdata[gdpdata['UN_Region']=='Europe'] # Task 9c: Create a subset Europe
europe
# Out:
#      Unnamed: 0       Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0             1                  Monaco    Europe             0         0
# 1             2           Liechtenstein    Europe             0         0
# 2             3              Luxembourg    Europe        132372      2023
# 3             4                 Ireland    Europe        114581      2023
# 5             6                  Norway    Europe        101103      2023
# 6             7             Switzerland    Europe         98767      2023
# 8             9             Isle of Man    Europe             0         0
# 12           13                 Iceland    Europe         75180      2023
# 13           14         Channel Islands    Europe             0         0
# 14           15           Faroe Islands    Europe             0         0
# 15           16                 Denmark    Europe         68827      2023
# 17           18             Netherlands    Europe         61098      2023
# ...

# %%
africa.describe() # Task 9d: Summary Statistic for Africa
# Out:
#        Unnamed: 0  IMF_Estimate     IMF_Year  WorldBank_Estimate  \
# count   55.000000     55.000000    55.000000           55.000000
# mean   178.818182   2802.345455  1986.218182         2470.836364
# std     35.501743   3421.329481   272.781264         2772.447680
# min     74.000000      0.000000     0.000000            0.000000
# 25%    156.500000    833.000000  2023.000000          762.000000
# 50%    188.000000   1475.000000  2023.000000         1319.000000
# 75%    206.500000   3696.000000  2023.000000         3221.500000
# max    223.000000  19536.000000  2023.000000        14653.000000
#
#        WorldBank_Year   UN_Estimate
# count       55.000000     55.000000
# mean      1983.963636   2417.927273
# std        272.476092   2521.291930
# min          0.000000    311.000000
# 25%       2021.000000    779.000000
# 50%       2021.000000   1361.000000
# 75%       2021.000000   3320.500000
# max       2021.000000  12085.000000

# %%
europe.describe() # Task 9e: Summary Statistic for Europe
# Out:
#        Unnamed: 0   IMF_Estimate     IMF_Year  WorldBank_Estimate  \
# count   48.000000      48.000000    48.000000           48.000000
# mean    52.687500   34446.750000  1812.270833        45193.687500
# std     40.319024   31085.656917   624.518870        43984.130016
# min      1.000000       0.000000     0.000000         4836.000000
# 25%     19.500000   10192.500000  2023.000000        16978.250000
# 50%     46.000000   27053.000000  2023.000000        31795.500000
# 75%     75.750000   51774.500000  2023.000000        58583.250000
# max    143.000000  132372.000000  2023.000000       234316.000000
#
#        WorldBank_Year    UN_Estimate
# count       48.000000      48.000000
# mean      2020.625000   40610.791667
# std          2.038199   45233.986703
# min       2007.000000       0.000000
# 25%       2021.000000   11468.250000
# 50%       2021.000000   27400.000000
# 75%       2021.000000   51800.250000
# max       2021.000000  234317.000000

# %%
america = gdpdata[gdpdata['UN_Region']=='Americas']
america.describe()
# Out:
#        Unnamed: 0  IMF_Estimate     IMF_Year  WorldBank_Estimate  \
# count   48.000000     48.000000    48.000000            48.00000
# mean    89.479167  11871.041667  1517.250000         18565.12500
# std     43.648007  15227.831902   885.254633         22769.88621
# min      5.000000      0.000000     0.000000             0.00000
# 25%     65.750000   1629.750000  1517.250000          5946.75000
# 50%     87.000000   6829.500000  2023.000000         10022.50000
# 75%    121.750000  17469.250000  2023.000000         18789.50000
# max    177.000000  80034.000000  2023.000000        114090.00000
#
#        WorldBank_Year    UN_Estimate
# count       48.000000      48.000000
# mean      1894.270833   18703.750000
# std        494.276593   22783.712986
# min          0.000000       0.000000
# 25%       2021.000000    6017.500000
# 50%       2021.000000   10403.500000
# 75%       2021.000000   18366.250000
# max       2021.000000  112653.000000

# %%
asia = gdpdata[gdpdata['UN_Region']=='Asia']
asia.describe()
# Out:
#        Unnamed: 0  IMF_Estimate     IMF_Year  WorldBank_Estimate  \
# count   51.000000     51.000000    51.000000           51.000000
# mean   119.764706  16665.254902  1943.509804        13921.313725
# std     62.873711  21375.993483   396.555790        18403.393872
# min      8.000000      0.000000     0.000000            0.000000
# 25%     55.500000   2516.000000  2023.000000         2357.500000
# 50%    129.000000   6180.000000  2023.000000         4566.000000
# 75%    172.000000  29153.500000  2023.000000        21348.000000
# max    222.000000  91100.000000  2023.000000        72794.000000
#
#        WorldBank_Year   UN_Estimate
# count       51.000000     51.000000
# mean      1941.607843  14069.019608
# std        396.167595  18159.078912
# min          0.000000      0.000000
# 25%       2021.000000   2153.000000
# 50%       2021.000000   4967.000000
# 75%       2021.000000  21347.500000
# max       2021.000000  66822.000000

# %%
oceania = gdpdata[gdpdata['UN_Region']=='Oceania']
oceania.describe()
# Out:
#        Unnamed: 0  IMF_Estimate     IMF_Year  WorldBank_Estimate  \
# count   20.000000     20.000000    20.000000           20.000000
# mean   105.800000   9133.150000  1416.100000        15113.650000
# std     51.032085  17001.622425   951.138426        17416.040076
# min     17.000000      0.000000     0.000000            0.000000
# 25%     68.500000      0.000000     0.000000         3427.500000
# 50%    115.000000   3926.500000  2023.000000         5902.000000
# 75%    146.250000   5917.000000  2023.000000        20863.000000
# max    179.000000  64964.000000  2023.000000        60443.000000
#
#        WorldBank_Year   UN_Estimate
# count       20.000000     20.000000
# mean      1919.850000  12613.750000
# std        451.886021  17964.815911
# min          0.000000      0.000000
# 25%       2021.000000   2581.250000
# 50%       2021.000000   4549.000000
# 75%       2021.000000  14108.500000
# max       2021.000000  66916.000000
