# %%
import pandas as pd
data=pd.read_csv('cereal.csv')
data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
data.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
data.shape
# Out:
# (77, 16)

# %%
data.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.mfr.value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# Q     8
# R     8
# N     6
# A     1
# Name: count, dtype: int64

# %%
sns.countplot(y='mfr',data=data)
# Out:
# <Axes: xlabel='count', ylabel='mfr'>

# %%
plt.pie(data['mfr'].value_counts(),labels=['K','G','P','R','Q','P','A'],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2c651292d50>,
# ...
#  [Text(0.6501892803051899, 0.8872732948625353, 'K'),
#   Text(-1.0266701582556739, 0.39490300853155025, 'G'),
#   Text(-0.6858387877960629, -0.8600146261281998, 'P'),
#   Text(0.022438373412025387, -1.0997711213696342, 'R'),
#   Text(0.6858387676659675, -0.860014642181415, 'Q'),
#   Text(1.0419233031728248, -0.352697930679257, 'P'),
#   Text(1.0990845779679979, -0.04486747678339531, 'A')],
#  [Text(0.35464869834828533, 0.483967251743201, '29.87%'),
#   Text(-0.5600019045030948, 0.2154016410172092, '28.57%'),
#   Text(-0.37409388425239787, -0.469098886979018, '11.69%'),
#   Text(0.012239112770195666, -0.5998751571107095, '10.39%'),
#   Text(0.3740938732723459, -0.46909889573531716, '10.39%'),
#   Text(0.5683218017306316, -0.19238068946141287, '7.79%'),
#   Text(0.599500678891635, -0.02447316915457926, '1.30%')])

# %%
data.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'calories'}>,
#         <Axes: title={'center': 'protein'}>,
#         <Axes: title={'center': 'fat'}>,
#         <Axes: title={'center': 'sodium'}>],
#        [<Axes: title={'center': 'fiber'}>,
#         <Axes: title={'center': 'carbo'}>,
#         <Axes: title={'center': 'sugars'}>,
#         <Axes: title={'center': 'potass'}>],
#        [<Axes: title={'center': 'vitamins'}>,
#         <Axes: title={'center': 'shelf'}>,
#         <Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'cups'}>],
#        [<Axes: title={'center': 'rating'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data.calories.hist(figsize=(6,6))
# Out:
# <Axes: >

# %%
data.vitamins.hist(figsize=(6,6))
# Out:
# <Axes: >

# %%
corrsubset = data.iloc[0:,3:16]
corrsubset
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70        4    1     130   10.0    5.0       6     280        25
# 1        120        3    5      15    2.0    8.0       8     135         0
# 2         70        4    1     260    9.0    7.0       5     320        25
# 3         50        4    0     140   14.0    8.0       0     330        25
# 4        110        2    2     200    1.0   14.0       8      -1        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 72       110        2    1     250    0.0   21.0       3      60        25
# 73       110        1    1     140    0.0   13.0      12      25        25
# 74       100        3    1     230    3.0   17.0       3     115        25
# 75       100        3    1     200    3.0   17.0       3     110        25
# 76       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups     rating
# ...

# %%
corr=corrsubset.corr()
round(corr,2)
# Out:
#           calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# calories      1.00     0.02  0.50    0.30  -0.29   0.25    0.56   -0.07
# protein       0.02     1.00  0.21   -0.05   0.50  -0.13   -0.33    0.55
# fat           0.50     0.21  1.00   -0.01   0.02  -0.32    0.27    0.19
# sodium        0.30    -0.05 -0.01    1.00  -0.07   0.36    0.10   -0.03
# fiber        -0.29     0.50  0.02   -0.07   1.00  -0.36   -0.14    0.90
# carbo         0.25    -0.13 -0.32    0.36  -0.36   1.00   -0.33   -0.35
# sugars        0.56    -0.33  0.27    0.10  -0.14  -0.33    1.00    0.02
# potass       -0.07     0.55  0.19   -0.03   0.90  -0.35    0.02    1.00
# vitamins      0.27     0.01 -0.03    0.36  -0.03   0.26    0.13    0.02
# shelf         0.10     0.13  0.26   -0.07   0.30  -0.10    0.10    0.36
# weight        0.70     0.22  0.21    0.31   0.25   0.14    0.45    0.42
# cups          0.09    -0.24 -0.18    0.12  -0.51   0.36   -0.03   -0.50
# ...

# %%
sns.heatmap(round(corr,2),annot=True)
plt.figure(figsize=(20,20))

# %%
CaloPro = data.iloc[0:,3:5]
CaloPro
# Out:
#     calories  protein
# 0         70        4
# 1        120        3
# 2         70        4
# 3         50        4
# 4        110        2
# ..       ...      ...
# 72       110        2
# 73       110        1
# 74       100        3
# 75       100        3
# 76       110        2
#
# [77 rows x 2 columns]

# %%
CaloProcorr=CaloPro.corr()
round(CaloProcorr,2)
# Out:
#           calories  protein
# calories      1.00     0.02
# protein       0.02     1.00

# %%
sns.heatmap(round(CaloProcorr,2),annot=True)
# Out:
# <Axes: >

# %%
data.plot(x='calories',y='protein',kind='scatter')
# Out:
# <Axes: xlabel='calories', ylabel='protein'>

# %%
sns.boxplot(data['calories'],orient='h')
# Out:
# <Axes: >

# %%
round(data.calories.describe(),2)
# Out:
# count     77.00
# mean     106.88
# std       19.48
# min       50.00
# 25%      100.00
# 50%      110.00
# 75%      110.00
# max      160.00
# Name: calories, dtype: float64

# %%
# Q1 = 25th = 100
# Q3 = 75th = 110
# IQR = Q3 - Q1 = 10
# LW = Q1 - 1.5*IQR = 85 --> there are outliers on the left (less than 85)
# RW = Q3 + 1.5*IQR = 125 --> there are outliers on the right (over than 125)

# %%
excloutlierscalories=data[(data['calories']>=85) & (data['calories']<=125)]
excloutlierscalories # Subset that remove the outsiders for calories factor
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 1         100% Natural Bran   Q    C       120        3    5      15    2.0
# 4            Almond Delight   R    C       110        2    2     200    1.0
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6               Apple Jacks   K    C       110        2    0     125    1.0
# 8                 Bran Chex   R    C        90        2    1     200    4.0
# ..                      ...  ..  ...       ...      ...  ...     ...    ...
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
sns.boxplot(data['fiber'],orient='h')
# Out:
# <Axes: >

# %%
round(data.fiber.describe(),2)
# Out:
# count    77.00
# mean      2.15
# std       2.38
# min       0.00
# 25%       1.00
# 50%       2.00
# 75%       3.00
# max      14.00
# Name: fiber, dtype: float64

# %%
# Q1 = 25th = 1
# Q3 = 75th = 3
# IQR = Q3 - Q1 = 2
# LW = Q1 - 1.5*IQR = -2 --> there are no outliers on the left
# RW = Q3 + 1.5*IQR = 6 --> there are outliers on the right (over 6)

# %%
excloutliersfiber=data[data['fiber']<=6]
excloutliersfiber # Subset that remove the outsiders for fiber factor
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 1         100% Natural Bran   Q    C       120        3    5      15    2.0
# 4            Almond Delight   R    C       110        2    2     200    1.0
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6               Apple Jacks   K    C       110        2    0     125    1.0
# 7                   Basic 4   G    C       130        3    2     210    2.0
# ..                      ...  ..  ...       ...      ...  ...     ...    ...
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
sns.boxplot(data['sugars'],orient='h')
# Out:
# <Axes: >

# %%
round(data.sugars.describe(),2)
# Out:
# count    77.00
# mean      6.92
# std       4.44
# min      -1.00
# 25%       3.00
# 50%       7.00
# 75%      11.00
# max      15.00
# Name: sugars, dtype: float64

# %%
# Q1 = 25th = 3
# Q3 = 75th = 11
# IQR = Q3 - Q1 = 8
# LW = Q1 - 1.5*IQR = -9 --> there are no outliers on the left
# RW = Q3 + 1.5*IQR = 23 --> there are no outliers on the right

# %%
sns.boxplot(data['carbo'],orient='h')
# Out:
# <Axes: >

# %%
round(data.carbo.describe(),2)
# Out:
# count    77.00
# mean     14.60
# std       4.28
# min      -1.00
# 25%      12.00
# 50%      14.00
# 75%      17.00
# max      23.00
# Name: carbo, dtype: float64

# %%
# Q1 = 25th = 12
# Q3 = 75th = 17
# IQR = Q3 - Q1 = 5
# LW = Q1 - 1.5*IQR = 4.5 --> there are outliers on the left (less than 4.5)
# RW = Q3 + 1.5*IQR = 24.5 --> there are no outliers on the right

# %%
excloutlierscarbo=data[data['carbo']>=4.5]
excloutlierscarbo # Subset that remove the outsiders for carbo factor
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
sns.boxplot(data,orient='h')
# Out:
# <Axes: >

# %%
data["calories"].corr(data["protein"]) # Correlation between calories and Protein
# Out:
# 0.019066068232357035
